# %%
import cv2
import time
import datetime
from vidgear.gears import VideoGear
import matplotlib.pyplot as plt
import numpy as np
import requests
# Specify the paths for the 2 files
protoFile = "C:/Users/NRRU/Desktop/python/openpose_pose_coco.prototxt"
weightsFile = "C:/Users/NRRU/Desktop/python/pose_iter_440000.caffemodel"
# Read the network into Memory
net = cv2.dnn.readNetFromCaffe(protoFile, weightsFile)
global status

def process_image(frame):
    status = False
    frameCopy = np.copy(frame)
    frameWidth = frame.shape[1]
    frameHeight = frame.shape[0]
    threshold = 0.1

    # Specify the input image dimensions
    inWidth = 200
    inHeight = 200

    POSE_PAIRS = [ [1,0],[1,2],[1,5],[2,3],[3,4],[5,6],[6,7],[1,8],[8,9],[9,10],[1,11],[11,12],[12,13],[0,14],[0,15],[14,16],[15,17]]

    # Prepare the frame to be fed to the network
    inpBlob = cv2.dnn.blobFromImage(frame, 1.0 / 255, (inWidth, inHeight), (0, 0, 0), swapRB=False, crop=False)

    # Set the prepared object as the input blob of the network
    net.setInput(inpBlob)

    output = net.forward()

    H = output.shape[2]
    W = output.shape[3]
    # Empty list to store the detected keypoints
    points = []
    for i in range(18):
        # confidence map of corresponding body's part.
        probMap = output[0, i, :, :]
     
        # Find global maxima of the probMap.
        minVal, prob, minLoc, point = cv2.minMaxLoc(probMap)
         
        # Scale the point to fit on the original image
        x = (frameWidth * point[0]) / W
        y = (frameHeight * point[1]) / H
     
        if prob > threshold : 
            cv2.circle(frame, (int(x), int(y)), 10, (0, 255, 255), thickness=-1, lineType=cv2.FILLED)
            #cv2.putText(frame, "{}".format(i), (int(x), int(y)), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 3, lineType=cv2.LINE_AA)
            # Add the point to the list if the probability is greater than the threshold
            points.append((int(x), int(y)))
            status = True
        else :
            points.append(None)
            status = False

    for pair in POSE_PAIRS:
        partA = pair[0]
        partB = pair[1]

        if points[partA] and points[partB]:
            cv2.line(frame, points[partA], points[partB], (0, 255, 255), 2)
            cv2.circle(frame, points[partA], 5, (0, 0, 255), thickness=-1, lineType=cv2.FILLED)
    return frame,status

# %%
stream = VideoGear(source=0).start()
global start
start = time.time()
while stream:
    frame = stream.read()
    frame,_person = process_image(frame)
    if (time.time() - start > 1) and (_person):
        start = time.time()
        to_day_time = datetime.datetime.now()
        server_url = "http://10.27.31.45/index.php?name='โทนเข้ามาทำไม : {}'".format(to_day_time)
        requests.get(server_url)
        status = False
        print("ตรวจสอบพบคนในภาพ")
    
    cv2.imshow("Output-Keypoints",frame)
    if cv2.waitKey(1) & 0xFF == ord('q') :
        break

stream.stop()
cv2.destroyAllWindows()
# Out:
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
# ตรวจสอบพบคนในภาพ
